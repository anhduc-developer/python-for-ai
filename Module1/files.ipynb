# %%
def two_sum(data, target):
    num_indices = {}
    for i, num in  enumerate(data):
        complement = target - num
        if complement in data:
            if(i != data.index(complement)):
                return [i, data.index(complement)]
    return []
data = [4,1, 2]
target = 8
print(two_sum(data, target))
# Out:
# []
